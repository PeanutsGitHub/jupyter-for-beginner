# %% [markdown]
# <a href="https://colab.research.google.com/github/PeanutsGitHub/jupyter-for-beginner/blob/main/Python-Matplotlib/03-PieCharts/finished_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt

# %%
import os
# Change the current working directory
# os.chdir(os.path.dirname(__file__))  # Python .py
os.chdir(os.path.abspath(''))  # Python & Python Notebook .ipynb

# %%
slices = [59219, 55466, 47544, 36443, 35917]
labels = ['JavaScript', 'HTML/CSS', 'SQL', 'Python', 'Java']
explode = [0, 0, 0, 0.1, 0]

# %%
#Ref: https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html
plt.style.use("fivethirtyeight")

plt.pie(slices, labels=labels, explode=explode, shadow=True,
        startangle=90, autopct='%1.1f%%',
        wedgeprops={'edgecolor': 'black'})

plt.title("My Awesome Pie Chart")
plt.tight_layout()
plt.show()
