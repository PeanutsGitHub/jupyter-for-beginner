# %% [markdown]
# <a href="https://colab.research.google.com/github/PeanutsGitHub/jupyter-for-beginner/blob/main/methods-for-using-git-with-google-colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q xlrd
# !git clone https://github.com/fastai/courses.git
# Out:
# Cloning into 'courses'...
# remote: Enumerating objects: 772, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 772 (delta 0), reused 1 (delta 0), pack-reused 769
# Receiving objects: 100% (772/772), 23.06 MiB | 30.08 MiB/s, done.
# Resolving deltas: 100% (409/409), done.

# %%
# Files from the cloned git repository.
# !ls courses/deeplearning1/excel
# Out:
# collab_filter.xlsx  entropy_example.xlsx  layers_example.xlsx
# conv-example.xlsx   graddesc.xlsm

# %%
import pandas as pd
df = pd.read_excel('courses/deeplearning1/excel/layers_example.xlsx')
df
# Out:
#     Unnamed: 0                  x1        x2         x3  Unnamed: 4  \
# 0          NaN                   2  3.000000   1.000000         NaN
# 1          NaN                 NaN       NaN        NaN         NaN
# 2          NaN           weights 1       NaN        NaN         NaN
# 3          NaN            1.777523 -0.056013   0.222363   -0.125313
# 4          NaN             0.58263 -0.153056   0.122250    0.597437
# 5          NaN            0.385083  0.402703   0.107784   -1.325171
# 6          NaN                 NaN       NaN        NaN         NaN
# 7          NaN       activations 1       NaN        NaN         NaN
# 8          NaN             5.68802 -0.168491   0.919260    0.216514
# 9          NaN             5.68802  0.000000   0.919260    0.216514
# 10         NaN                 NaN       NaN        NaN         NaN
# 11         NaN           weights 2       NaN        NaN         NaN
# 12         NaN           -1.010764  0.470262   0.246334         NaN
# ...
